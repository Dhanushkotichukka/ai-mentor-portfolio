# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanushkotichukka/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Enter Your API key: ')
# Out:
# Enter Your API key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid illustrates the breadth of skills needed in AI, from foundational to strategic:
#
# *   **Base (Layers 1-2):** Foundational skills start with data acquisition, preparation, and infrastructure management (Data Engineers, MLOps).
# *   **Middle (Layer 3):** Progresses to core machine learning development, model building, and deep domain expertise (Data Scientists, ML Engineers).
# *   **Upper (Layer 4):** Involves advanced AI research, developing novel algorithms, and pushing the boundaries of the field.
# *   **Apex (Layer 5):** The pinnacle focuses on AI strategy, ethical considerations, governance, and leadership to guide responsible AI implementation and impact.
